# %% [markdown]
# # Jordan P

# %% [markdown]
# ## Research question/interests
#
# I will being answering the question do genres impact a films budget? how does popularity of a genre over time affect a films budget?

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("../data/raw/top_movies.csv")
df
# Out:
#       production_year       id                                       title  \
# 0                2006  4103791  Pirates of the Caribbean: Dead Man's Chest
# 1                2006  4022547                         Night at the Museum
# 2                2006  3415583                                        Cars
# 3                2006  4587958                       X-Men: The Last Stand
# 4                2006  4351263                           The Da Vinci Code
# ...               ...      ...                                         ...
# 1190             2017  3954779                                Megan Leavey
# 1191             2017  4375083                        The Greatest Showman
# 1192             2016  4367698                                 The Founder
# 1193             2017  3342703                         Battle of the Sexes
# 1194             2017  4332562                                The Beguiled
#
#                             directors  \
# ...

# %%
df.head()
# Out:
#    production_year       id                                       title  \
# 0             2006  4103791  Pirates of the Caribbean: Dead Man's Chest
# 1             2006  4022547                         Night at the Museum
# 2             2006  3415583                                        Cars
# 3             2006  4587958                       X-Men: The Last Stand
# 4             2006  4351263                           The Da Vinci Code
#
#                    directors                                    genres  \
# 0            Verbinski, Gore                  Action|Adventure|Fantasy
# 1                Levy, Shawn           Adventure|Comedy|Family|Fantasy
# 2  Lasseter, John|Ranft, Joe             Animation|Comedy|Family|Sport
# 3              Ratner, Brett  Action|Adventure|Fantasy|Sci-Fi|Thriller
# 4                Howard, Ron                          Mystery|Thriller
#
#                                        camera_format negative_format  \
# ...

# %% [markdown]
# grabbing the first 5 rows and columns

# %%
df.describe().apply(lambda s: s.apply(lambda x: format(x,'f')))
# Out:
#       production_year              id            budget
# count     1195.000000     1195.000000       1195.000000
# mean      2011.492887  3974297.446025   65826104.602510
# std          3.434807   408547.436479   59738936.941028
# min       2006.000000  3212915.000000          0.000000
# 25%       2008.500000  3634968.500000   22250000.000000
# 50%       2011.000000  4022548.000000   45000000.000000
# 75%       2014.000000  4361249.500000   90000000.000000
# max       2017.000000  4607464.000000  378500000.000000

# %% [markdown]
# finding mean,max,min etc for production year, id , budget

# %%
sns.displot(x = df['budget'], hue = df['film_type'])

# %% [markdown]
# displot showing the correllation between budget and movie types

# %%
sns.barplot(data=df, y = df['budget'], x = df['production_year'])
# Out:
# <AxesSubplot:xlabel='production_year', ylabel='budget'>

# %% [markdown]
# barplot showing how the budget of movies has changed per year (2006-2017)

# %%
sns.jointplot(x=df['production_year'], y = df['budget'], data = df)

# %% [markdown]
# jointplot providing another another look at budgets for films per year

# %% [markdown]
# Data Analysis pipleline

# %%
dfcopy = df.copy().drop(['budget_source','negative_format','id'], axis = 1)
cleaned = dfcopy[df['budget']>0]
cleaned = cleaned.dropna(axis =0)
cleaned.head()
# Out:
#    production_year                                       title  \
# 0             2006  Pirates of the Caribbean: Dead Man's Chest
# 1             2006                         Night at the Museum
# 3             2006                       X-Men: The Last Stand
# 4             2006                           The Da Vinci Code
# 5             2006                            Superman Returns
#
#          directors                                    genres  \
# 0  Verbinski, Gore                  Action|Adventure|Fantasy
# 1      Levy, Shawn           Adventure|Comedy|Family|Fantasy
# 3    Ratner, Brett  Action|Adventure|Fantasy|Sci-Fi|Thriller
# 4      Howard, Ron                          Mystery|Thriller
# 5    Singer, Bryan                   Action|Adventure|Sci-Fi
#
#                                        camera_format     budget film_type
# 0  Arriflex 235, Panavision Primo Lenses|Panavisi...  225000000         F
# ...

# %% [markdown]
# -cleaned data by dropping columns not used (budget source, id etc), dropped null values, made it so budget can only be greater than 0

# %% [markdown]
# Method Chaining

# %%
import project_functions3 as j
dfc = j.load("../data/raw/top_movies.csv")
dfc
# Out:
#       production_year       id                                       title  \
# 0                2006  4103791  Pirates of the Caribbean: Dead Man's Chest
# 1                2006  4022547                         Night at the Museum
# 3                2006  4587958                       X-Men: The Last Stand
# 4                2006  4351263                           The Da Vinci Code
# 5                2006  4292783                            Superman Returns
# ...               ...      ...                                         ...
# 1188             2017  3773879                           It Comes at Night
# 1191             2017  4375083                        The Greatest Showman
# 1192             2016  4367698                                 The Founder
# 1193             2017  3342703                         Battle of the Sexes
# 1194             2017  4332562                                The Beguiled
#
#                             directors  \
# ...

# %%
dfc.to_csv('mile4.csv')

# %% [markdown]
# # Analysis(Task 4 Milestone 3)

# %%
import project_functions3 as p3
df = pd.read_csv("../data/raw/top_movies.csv")
df
# Out:
#       production_year       id                                       title  \
# 0                2006  4103791  Pirates of the Caribbean: Dead Man's Chest
# 1                2006  4022547                         Night at the Museum
# 2                2006  3415583                                        Cars
# 3                2006  4587958                       X-Men: The Last Stand
# 4                2006  4351263                           The Da Vinci Code
# ...               ...      ...                                         ...
# 1190             2017  3954779                                Megan Leavey
# 1191             2017  4375083                        The Greatest Showman
# 1192             2016  4367698                                 The Founder
# 1193             2017  3342703                         Battle of the Sexes
# 1194             2017  4332562                                The Beguiled
#
#                             directors  \
# ...

# %%
dfp = p3.load("../data/raw/top_movies.csv")
dfp
# Out:
#       production_year       id                                       title  \
# 0                2006  4103791  Pirates of the Caribbean: Dead Man's Chest
# 1                2006  4022547                         Night at the Museum
# 3                2006  4587958                       X-Men: The Last Stand
# 4                2006  4351263                           The Da Vinci Code
# 5                2006  4292783                            Superman Returns
# ...               ...      ...                                         ...
# 1188             2017  3773879                           It Comes at Night
# 1191             2017  4375083                        The Greatest Showman
# 1192             2016  4367698                                 The Founder
# 1193             2017  3342703                         Battle of the Sexes
# 1194             2017  4332562                                The Beguiled
#
#                             directors  \
# ...

# %%
dfp.describe()
# Out:
#        production_year            id        budget
# count      1008.000000  1.008000e+03  1.008000e+03
# mean       2011.531746  3.984895e+06  6.537986e+07
# std           3.341679  4.077355e+05  5.962609e+07
# min        2006.000000  3.212915e+06  1.000000e+05
# 25%        2009.000000  3.654095e+06  2.475000e+07
# 50%        2012.000000  4.029979e+06  4.200000e+07
# 75%        2014.000000  4.365436e+06  8.500000e+07
# max        2017.000000  4.607372e+06  3.785000e+08

# %%
sns.jointplot(x = dfp['budget'], y = dfp['production_year'], data = dfp)
plt.savefig('yearvsbudget.png')

# %% [markdown]
# Firstly, this jointplot shows the differences in budgets from year to year. As we can budgets have relatively stayed the same from 2006 to 2017.

# %%
dfcopy = dfp.copy()
df2017 = dfcopy[dfcopy['production_year'] > 2016]
df20172 = df2017[df2017['budget'] > 100000000]
sns.set(font_scale = 0.5)
sns.barplot(x = df20172['budget'], y = df20172['genres'], color='orange',errorbar = None)
plt.title("Genre Vs Budget 2017")
plt.savefig('genrevsbudget2017.png',bbox_inches="tight",dpi=200)

# %%
dfcopy2 = dfp.copy()
df2006 = dfcopy2[dfcopy2['production_year'] < 2007]
df20062 = df2006[df2006['budget'] > 100000000]

sns.set(font_scale = 0.5)
sns.barplot(x = df20062['budget'], y = df20062['genres'],color='orange', errorbar = None)
plt.title("Genre Vs Budget 2006")
plt.savefig('genrevsbudget2006.png', bbox_inches="tight",dpi=200)

# %% [markdown]
# Two barplots showing the top budgets for films in 2006 and 2017(budgets over 150 million), we can see that action is the dominate genre in terms of budgets amongst films. There are some outliers but generally it is Action that takes the highest budget. We can see the subgenres are different but there main genre is still Action. This I believe to be due to Action films requiring stunts, extra staff in the form of stunt double, props used like cars etc. These films require alot of planning and upfront cost.

# %%
dfcopy = dfp.copy()
df2017 = dfcopy[dfcopy['budget'] > 200000000]
sns.set(font_scale = 0.5)
sns.jointplot(x = df2017['directors'], y = df2017['budget'])
plt.xticks(rotation=90)
plt.savefig('directorsbudget.png')

# %% [markdown]
# This is a jointplot of what directors had the highest budgets between 2006 and 2017.

# %% [markdown]
# Conclusion
# As we can see the data shows that we over the the time period of 2006 to 2017 movie budgets relatively stay the same from year to year. Looking at the two barplots we find that Action movies almost always yeild the highest budgets amongst its counterparts and that begs the question do genres impact a films budget? looking at the data we can see that a genre can impact a films budget immensely, for example an action move will require a higher budget due to stunts, explosions etc compared to a drama film which is purely acting.
